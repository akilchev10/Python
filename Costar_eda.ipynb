# %%
import pandas as pd

# plotting
import matplotlib.pyplot as plt
import seaborn as sns

# %%
costar_df = pd.read_excel(r'Sample Apartment and concessions Data.xlsx',index_col=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 costar_df = pd.read_excel(r'Sample Apartment and concessions Data.xlsx',index_col=0)
# ----> 2 head(costat_df)
#
# NameError: name 'head' is not defined

# %%
costar_df.head()
# Out:
#             ApartmentModelID  ApartmentDataSourceID ObservationDateDaily
# PropertyID
# 7761149              1141594                      4           2018-02-21  \
# 7761149              1141595                      4           2018-02-21
# 7761149              1141598                      4           2018-02-21
# 7761149              1141599                      4           2018-02-21
# 7761149              1141601                      4           2018-02-21
#
#                    ObservationDate  ApartmentRentID  ApartmentUnitID  MinRent
# PropertyID
# 7761149    2018-02-21 14:21:39.087       1535470284              NaN      699  \
# 7761149    2018-02-21 14:21:45.250       1535470824              NaN      769
# 7761149    2018-02-21 14:21:45.343       1535470839              NaN      899
# 7761149    2018-02-21 14:21:45.460       1535470875              NaN      989
# 7761149    2018-02-21 14:21:46.497       1535470929              NaN     1125
#
# ...

# %%
costar_df.columns
# Out:
# Index(['ApartmentModelID', 'ApartmentDataSourceID', 'ObservationDateDaily',
#        'ObservationDate', 'ApartmentRentID', 'ApartmentUnitID', 'MinRent',
#        'RentBasisID', 'UpdatedDate', 'PropertyApartmentID', 'AvailableOnDate',
#        'NumUnitsAvailable', 'MonthlyDiscount', 'NumFreeMonths',
#        'TotalConcessionValue'],
#       dtype='object')

# %%
costar_df.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 costar_df.describe()
#
# NameError: name 'costar_df' is not defined

# %%
costar_df.count(0)
# Out:
# ApartmentModelID         79490
# ApartmentDataSourceID    79490
# ObservationDateDaily     79490
# ObservationDate          79490
# ApartmentRentID          79490
# ApartmentUnitID              0
# MinRent                  79490
# RentBasisID              79490
# UpdatedDate              79490
# PropertyApartmentID      79490
# AvailableOnDate              0
# NumUnitsAvailable            0
# MonthlyDiscount          69795
# NumFreeMonths            70143
# TotalConcessionValue     70092
# dtype: int64

# %%
costar_df.mean(0)
# Out:
# ApartmentModelID                        1669208.770386
# ApartmentDataSourceID                              4.0
# ObservationDateDaily     2021-04-13 15:39:42.277016064
# ObservationDate          2021-04-14 05:18:30.606597376
# ApartmentRentID                      6545583355.499962
# ApartmentUnitID                                    NaN
# MinRent                                    1190.741037
# RentBasisID                                        1.0
# UpdatedDate              2021-04-14 05:18:30.627143936
# PropertyApartmentID                      5160979.24388
# AvailableOnDate                                    NaN
# NumUnitsAvailable                                  NaN
# MonthlyDiscount                               0.656981
# NumFreeMonths                                  0.14996
# TotalConcessionValue                         80.657136
# dtype: object

# %%
costar_df.sum(0,14)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 costar_df.sum(0,14)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\pandas\core\generic.py:11519, in NDFrame._add_numeric_operations.<locals>.sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#   11500 @doc(  # type: ignore[misc]
#   11501     _num_doc,
#   11502     desc="Return the sum of the values over the requested axis.\n\n"
#    (...)
#   11517     **kwargs,
#   11518 ):
# > 11519     return NDFrame.sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\pandas\core\generic.py:11287, in NDFrame.sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#   11279 def sum(
#   11280     self,
#   11281     axis: Axis | None = None,
#    (...)
#   11285     **kwargs,
#   11286 ):
# ...

# %%
costar_corr = costar_df.corr()

# %%
sns.heatmap(costar_corr, annot=False)
# Out:
# <Axes: >
